# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Projects/Emotion Detection/Data/fer2013/fer2013.csv')
print(df.head())
print(df.shape)

# %%
X_train = []
y_train = []
X_test = []
y_test = []
for index, row in df.iterrows():
    k = row['pixels'].split(" ")
    if row['Usage'] == 'Training':
        X_train.append(np.array(k))
        y_train.append(row['emotion'])
    elif row['Usage'] == 'PublicTest':
        X_test.append(np.array(k))
        y_test.append(row['emotion'])

# %%
X_train = np.array(X_train, dtype = 'uint8')
y_train = np.array(y_train, dtype = 'uint8')
X_test = np.array(X_test, dtype = 'uint8')
y_test = np.array(y_test, dtype = 'uint8')

# %%
import keras
from keras.utils import to_categorical
y_train= to_categorical(y_train, num_classes=7)
y_test = to_categorical(y_test, num_classes=7)

# %%
X_train = X_train.reshape(X_train.shape[0], 48, 48, 1)
X_test = X_test.reshape(X_test.shape[0], 48, 48, 1)

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range = 10,
    horizontal_flip = True,
    width_shift_range=0.1,
    height_shift_range=0.1,
    fill_mode = 'nearest')
testgen = ImageDataGenerator(rescale=1./255)
datagen.fit(X_train)
batch_size = 64

# %%
train_flow = datagen.flow(X_train, y_train, batch_size=batch_size)
test_flow = testgen.flow(X_test, y_test, batch_size=batch_size)

# %%
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from tensorflow.keras.layers import concatenate
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix

# %%
def FER_Model(input_shape=(48,48,1)):
    # first input model
    visible = Input(shape=input_shape, name='input')
    num_classes = 7
    #the 1-st block
    conv1_1 = Conv2D(64, kernel_size=3, activation='relu', padding='same', name = 'conv1_1')(visible)
    conv1_1 = BatchNormalization()(conv1_1)
    conv1_2 = Conv2D(64, kernel_size=3, activation='relu', padding='same', name = 'conv1_2')(conv1_1)
    conv1_2 = BatchNormalization()(conv1_2)
    pool1_1 = MaxPooling2D(pool_size=(2,2), name = 'pool1_1')(conv1_2)
    drop1_1 = Dropout(0.3, name = 'drop1_1')(pool1_1)#the 2-nd block
    conv2_1 = Conv2D(128, kernel_size=3, activation='relu', padding='same', name = 'conv2_1')(drop1_1)
    conv2_1 = BatchNormalization()(conv2_1)
    conv2_2 = Conv2D(128, kernel_size=3, activation='relu', padding='same', name = 'conv2_2')(conv2_1)
    conv2_2 = BatchNormalization()(conv2_2)
    conv2_3 = Conv2D(128, kernel_size=3, activation='relu', padding='same', name = 'conv2_3')(conv2_2)
    conv2_2 = BatchNormalization()(conv2_3)
    pool2_1 = MaxPooling2D(pool_size=(2,2), name = 'pool2_1')(conv2_3)
    drop2_1 = Dropout(0.3, name = 'drop2_1')(pool2_1)#the 3-rd block
    conv3_1 = Conv2D(256, kernel_size=3, activation='relu', padding='same', name = 'conv3_1')(drop2_1)
    conv3_1 = BatchNormalization()(conv3_1)
    conv3_2 = Conv2D(256, kernel_size=3, activation='relu', padding='same', name = 'conv3_2')(conv3_1)
    conv3_2 = BatchNormalization()(conv3_2)
    conv3_3 = Conv2D(256, kernel_size=3, activation='relu', padding='same', name = 'conv3_3')(conv3_2)
    conv3_3 = BatchNormalization()(conv3_3)
    conv3_4 = Conv2D(256, kernel_size=3, activation='relu', padding='same', name = 'conv3_4')(conv3_3)
    conv3_4 = BatchNormalization()(conv3_4)
    pool3_1 = MaxPooling2D(pool_size=(2,2), name = 'pool3_1')(conv3_4)
    drop3_1 = Dropout(0.3, name = 'drop3_1')(pool3_1)#the 4-th block
    conv4_1 = Conv2D(256, kernel_size=3, activation='relu', padding='same', name = 'conv4_1')(drop3_1)
    conv4_1 = BatchNormalization()(conv4_1)
    conv4_2 = Conv2D(256, kernel_size=3, activation='relu', padding='same', name = 'conv4_2')(conv4_1)
    conv4_2 = BatchNormalization()(conv4_2)
    conv4_3 = Conv2D(256, kernel_size=3, activation='relu', padding='same', name = 'conv4_3')(conv4_2)
    conv4_3 = BatchNormalization()(conv4_3)
    conv4_4 = Conv2D(256, kernel_size=3, activation='relu', padding='same', name = 'conv4_4')(conv4_3)
    conv4_4 = BatchNormalization()(conv4_4)
    pool4_1 = MaxPooling2D(pool_size=(2,2), name = 'pool4_1')(conv4_4)
    drop4_1 = Dropout(0.3, name = 'drop4_1')(pool4_1)

    #the 5-th block
    conv5_1 = Conv2D(512, kernel_size=3, activation='relu', padding='same', name = 'conv5_1')(drop4_1)
    conv5_1 = BatchNormalization()(conv5_1)
    conv5_2 = Conv2D(512, kernel_size=3, activation='relu', padding='same', name = 'conv5_2')(conv5_1)
    conv5_2 = BatchNormalization()(conv5_2)
    conv5_3 = Conv2D(512, kernel_size=3, activation='relu', padding='same', name = 'conv5_3')(conv5_2)
    conv5_3 = BatchNormalization()(conv5_3)
    conv5_4 = Conv2D(512, kernel_size=3, activation='relu', padding='same', name = 'conv5_4')(conv5_3)
    conv5_3 = BatchNormalization()(conv5_3)
    pool5_1 = MaxPooling2D(pool_size=(2,2), name = 'pool5_1')(conv5_4)
    drop5_1 = Dropout(0.3, name = 'drop5_1')(pool5_1)#Flatten and output
    flatten = Flatten(name = 'flatten')(drop5_1)
    ouput = Dense(num_classes, activation='softmax', name = 'output')(flatten)# create model
    model = Model(inputs =visible, outputs = ouput)
    # summary layers
    print(model.summary())

    return model

# %%
model = FER_Model()
opt = Adam(learning_rate=0.0001, beta_1=1e-6)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 48, 48, 1)]       0
#
#  conv1_1 (Conv2D)            (None, 48, 48, 64)        640
#
#  batch_normalization_68 (Ba  (None, 48, 48, 64)        256
#  tchNormalization)
#
#  conv1_2 (Conv2D)            (None, 48, 48, 64)        36928
#
#  batch_normalization_69 (Ba  (None, 48, 48, 64)        256
#  tchNormalization)
#
#  pool1_1 (MaxPooling2D)      (None, 24, 24, 64)        0
#
#  drop1_1 (Dropout)           (None, 24, 24, 64)        0
#
#  conv2_1 (Conv2D)            (None, 24, 24, 128)       73856
#
#  batch_normalization_70 (Ba  (None, 24, 24, 128)       512
#  tchNormalization)
#
#  conv2_2 (Conv2D)            (None, 24, 24, 128)       147584
#
#  batch_normalization_71 (Ba  (None, 24, 24, 128)       512
#  tchNormalization)
#
#  conv2_3 (Conv2D)            (None, 24, 24, 128)       147584
#
#  pool2_1 (MaxPooling2D)      (None, 12, 12, 128)       0
#
#  drop2_1 (Dropout)           (None, 12, 12, 128)       0
#
#  conv3_1 (Conv2D)            (None, 12, 12, 256)       295168
#
#  batch_normalization_73 (Ba  (None, 12, 12, 256)       1024
#  tchNormalization)
#
#  conv3_2 (Conv2D)            (None, 12, 12, 256)       590080
#
#  batch_normalization_74 (Ba  (None, 12, 12, 256)       1024
#  tchNormalization)
#
#  conv3_3 (Conv2D)            (None, 12, 12, 256)       590080
#
#  batch_normalization_75 (Ba  (None, 12, 12, 256)       1024
#  tchNormalization)
#
#  conv3_4 (Conv2D)            (None, 12, 12, 256)       590080
#
#  batch_normalization_76 (Ba  (None, 12, 12, 256)       1024
#  tchNormalization)
#
#  pool3_1 (MaxPooling2D)      (None, 6, 6, 256)         0
#
#  drop3_1 (Dropout)           (None, 6, 6, 256)         0
#
#  conv4_1 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_77 (Ba  (None, 6, 6, 256)         1024
#  tchNormalization)
#
#  conv4_2 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_78 (Ba  (None, 6, 6, 256)         1024
#  tchNormalization)
#
#  conv4_3 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_79 (Ba  (None, 6, 6, 256)         1024
#  tchNormalization)
#
#  conv4_4 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_80 (Ba  (None, 6, 6, 256)         1024
#  tchNormalization)
#
#  pool4_1 (MaxPooling2D)      (None, 3, 3, 256)         0
#
#  drop4_1 (Dropout)           (None, 3, 3, 256)         0
#
#  conv5_1 (Conv2D)            (None, 3, 3, 512)         1180160
#
#  batch_normalization_81 (Ba  (None, 3, 3, 512)         2048
#  tchNormalization)
#
#  conv5_2 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  batch_normalization_82 (Ba  (None, 3, 3, 512)         2048
#  tchNormalization)
#
#  conv5_3 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  batch_normalization_83 (Ba  (None, 3, 3, 512)         2048
#  tchNormalization)
#
#  conv5_4 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  pool5_1 (MaxPooling2D)      (None, 1, 1, 512)         0
#
#  drop5_1 (Dropout)           (None, 1, 1, 512)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  output (Dense)              (None, 7)                 3591
#
# =================================================================
# Total params: 13111367 (50.02 MB)
# Trainable params: 13103431 (49.99 MB)
# Non-trainable params: 7936 (31.00 KB)
# _________________________________________________________________
# None

# %%
num_epochs = 40
history = model.fit_generator(train_flow,
                    steps_per_epoch=len(X_train) / batch_size,
                    epochs=num_epochs,
                    verbose=1,
                    validation_data=test_flow,
                    validation_steps=len(X_test) / batch_size)
# Out:
# Epoch 1/40
# <ipython-input-27-6002add8a21a>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_flow,
# 448/448 [==============================] - 52s 97ms/step - loss: 2.0376 - accuracy: 0.2122 - val_loss: 1.9374 - val_accuracy: 0.2474
# Epoch 2/40
# 448/448 [==============================] - 41s 90ms/step - loss: 1.7884 - accuracy: 0.2577 - val_loss: 1.8006 - val_accuracy: 0.2566
# Epoch 3/40
# 448/448 [==============================] - 40s 90ms/step - loss: 1.7543 - accuracy: 0.2756 - val_loss: 1.9712 - val_accuracy: 0.2756
# Epoch 4/40
# 448/448 [==============================] - 40s 90ms/step - loss: 1.7017 - accuracy: 0.3128 - val_loss: 2.0344 - val_accuracy: 0.3179
# Epoch 5/40
# 448/448 [==============================] - 40s 90ms/step - loss: 1.6325 - accuracy: 0.3538 - val_loss: 1.6045 - val_accuracy: 0.3884
# Epoch 6/40
# 448/448 [==============================] - 40s 90ms/step - loss: 1.5695 - accuracy: 0.3853 - val_loss: 1.5154 - val_accuracy: 0.4135
# Epoch 7/40
# 448/448 [==============================] - 40s 90ms/step - loss: 1.5072 - accuracy: 0.4128 - val_loss: 1.5615 - val_accuracy: 0.4444
# Epoch 8/40
# 448/448 [==============================] - 40s 90ms/step - loss: 1.4389 - accuracy: 0.4448 - val_loss: 1.4594 - val_accuracy: 0.4597
# Epoch 9/40
# 448/448 [==============================] - 40s 90ms/step - loss: 1.3668 - accuracy: 0.4775 - val_loss: 1.3010 - val_accuracy: 0.5049
# Epoch 10/40
# 448/448 [==============================] - 40s 90ms/step - loss: 1.3092 - accuracy: 0.4989 - val_loss: 1.3229 - val_accuracy: 0.5157
# Epoch 11/40
# 448/448 [==============================] - 40s 90ms/step - loss: 1.2710 - accuracy: 0.5124 - val_loss: 1.2647 - val_accuracy: 0.5249
# Epoch 12/40
# 448/448 [==============================] - 40s 90ms/step - loss: 1.2253 - accuracy: 0.5308 - val_loss: 1.1777 - val_accuracy: 0.5483
# Epoch 13/40
# 448/448 [==============================] - 40s 90ms/step - loss: 1.1885 - accuracy: 0.5466 - val_loss: 1.1670 - val_accuracy: 0.5419
# Epoch 14/40
# 448/448 [==============================] - 40s 90ms/step - loss: 1.1594 - accuracy: 0.5592 - val_loss: 1.1172 - val_accuracy: 0.5787
# Epoch 15/40
# 448/448 [==============================] - 40s 90ms/step - loss: 1.1352 - accuracy: 0.5703 - val_loss: 1.1341 - val_accuracy: 0.5782
# Epoch 16/40
# 448/448 [==============================] - 40s 90ms/step - loss: 1.1160 - accuracy: 0.5800 - val_loss: 1.1057 - val_accuracy: 0.5812
# Epoch 17/40
# 448/448 [==============================] - 40s 90ms/step - loss: 1.0905 - accuracy: 0.5888 - val_loss: 1.1308 - val_accuracy: 0.5840
# Epoch 18/40
# 448/448 [==============================] - 40s 90ms/step - loss: 1.0788 - accuracy: 0.5907 - val_loss: 1.2409 - val_accuracy: 0.5417
# Epoch 19/40
# 448/448 [==============================] - 40s 90ms/step - loss: 1.0506 - accuracy: 0.6025 - val_loss: 1.1130 - val_accuracy: 0.5862
# Epoch 20/40
# 448/448 [==============================] - 40s 90ms/step - loss: 1.0344 - accuracy: 0.6083 - val_loss: 1.0502 - val_accuracy: 0.6060
# Epoch 21/40
# 448/448 [==============================] - 40s 90ms/step - loss: 1.0176 - accuracy: 0.6181 - val_loss: 1.0761 - val_accuracy: 0.6013
# Epoch 22/40
# 448/448 [==============================] - 40s 89ms/step - loss: 1.0058 - accuracy: 0.6222 - val_loss: 1.0620 - val_accuracy: 0.6149
# Epoch 23/40
# 448/448 [==============================] - 40s 90ms/step - loss: 0.9852 - accuracy: 0.6308 - val_loss: 1.0479 - val_accuracy: 0.6124
# Epoch 24/40
# 448/448 [==============================] - 40s 90ms/step - loss: 0.9700 - accuracy: 0.6353 - val_loss: 1.0422 - val_accuracy: 0.6158
# Epoch 25/40
# 448/448 [==============================] - 40s 90ms/step - loss: 0.9596 - accuracy: 0.6435 - val_loss: 1.0075 - val_accuracy: 0.6319
# Epoch 26/40
# 448/448 [==============================] - 40s 90ms/step - loss: 0.9439 - accuracy: 0.6468 - val_loss: 0.9915 - val_accuracy: 0.6303
# Epoch 27/40
# 448/448 [==============================] - 40s 90ms/step - loss: 0.9330 - accuracy: 0.6528 - val_loss: 1.0532 - val_accuracy: 0.6205
# Epoch 28/40
# 448/448 [==============================] - 40s 90ms/step - loss: 0.9234 - accuracy: 0.6562 - val_loss: 0.9829 - val_accuracy: 0.6397
# Epoch 29/40
# 448/448 [==============================] - 40s 90ms/step - loss: 0.9063 - accuracy: 0.6621 - val_loss: 0.9993 - val_accuracy: 0.6297
# Epoch 30/40
# 448/448 [==============================] - 40s 90ms/step - loss: 0.8921 - accuracy: 0.6644 - val_loss: 1.0149 - val_accuracy: 0.6333
# Epoch 31/40
# 448/448 [==============================] - 40s 90ms/step - loss: 0.8810 - accuracy: 0.6698 - val_loss: 1.0170 - val_accuracy: 0.6330
# Epoch 32/40
# 448/448 [==============================] - 40s 90ms/step - loss: 0.8675 - accuracy: 0.6738 - val_loss: 1.0117 - val_accuracy: 0.6308
# Epoch 33/40
# 448/448 [==============================] - 41s 90ms/step - loss: 0.8507 - accuracy: 0.6810 - val_loss: 0.9986 - val_accuracy: 0.6453
# Epoch 34/40
# 448/448 [==============================] - 41s 90ms/step - loss: 0.8424 - accuracy: 0.6841 - val_loss: 1.0027 - val_accuracy: 0.6395
# Epoch 35/40
# 448/448 [==============================] - 40s 90ms/step - loss: 0.8275 - accuracy: 0.6888 - val_loss: 1.0096 - val_accuracy: 0.6336
# Epoch 36/40
# 448/448 [==============================] - 40s 90ms/step - loss: 0.8218 - accuracy: 0.6943 - val_loss: 0.9436 - val_accuracy: 0.6581
# Epoch 37/40
# 448/448 [==============================] - 40s 90ms/step - loss: 0.8039 - accuracy: 0.6973 - val_loss: 0.9684 - val_accuracy: 0.6517
# Epoch 38/40
# 448/448 [==============================] - 40s 90ms/step - loss: 0.8024 - accuracy: 0.7000 - val_loss: 0.9689 - val_accuracy: 0.6500
# Epoch 39/40
# 448/448 [==============================] - 40s 90ms/step - loss: 0.7885 - accuracy: 0.7033 - val_loss: 0.9797 - val_accuracy: 0.6517
# Epoch 40/40
# 448/448 [==============================] - 40s 90ms/step - loss: 0.7768 - accuracy: 0.7104 - val_loss: 0.9723 - val_accuracy: 0.6556

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
model.save('my_model.keras')
